# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a9054e4e-0a05-4c1a-ba8f-122b17f2dc95" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a9054e4e-0a05-4c1a-ba8f-122b17f2dc95">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_excel("bank_Data.xlsx")
df.head()
# Out:
#   Transaction_ID       Date Customer_ID Customer_Name Account_Type  \
# 0      TXN000001 2024-01-01    CUST0001  Aarav Sharma      Savings
# 1      TXN000002 2024-01-02    CUST0002   Priya Patel      Current
# 2      TXN000003 2024-01-03    CUST0003   Rahul Verma       Credit
# 3      TXN000004 2024-01-04    CUST0004   Sneha Reddy      Savings
# 4      TXN000005 2024-01-05    CUST0005   Karan Singh      Current
#
#   Transaction_Type    Amount     Branch Channel Loan_Status  Credit_Score
# 0            Debit   2450.75     Mumbai     ATM    Approved           782
# 1           Credit  18500.00      Delhi  Online    Rejected           641
# 2            Debit    950.50  Bengaluru    Bank    Approved           815
# 3           Credit   4200.25  Hyderabad  Online    Approved           734
# 4            Debit  12750.00    Chennai     ATM    Rejected           602

# %%
print("Missing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Transaction_ID      0
# Date                0
# Customer_ID         0
# Customer_Name       0
# Account_Type        0
# Transaction_Type    0
# Amount              0
# Branch              0
# Channel             0
# Loan_Status         0
# Credit_Score        0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Month'] = df['Date'].dt.month

# %%
print(df.head())
# Out:
#   Transaction_ID       Date Customer_ID Customer_Name Account_Type  \
# 0      TXN000001 2024-01-01    CUST0001  Aarav Sharma      Savings
# 1      TXN000002 2024-01-02    CUST0002   Priya Patel      Current
# 2      TXN000003 2024-01-03    CUST0003   Rahul Verma       Credit
# 3      TXN000004 2024-01-04    CUST0004   Sneha Reddy      Savings
# 4      TXN000005 2024-01-05    CUST0005   Karan Singh      Current
#
#   Transaction_Type    Amount     Branch Channel Loan_Status  Credit_Score  \
# 0            Debit   2450.75     Mumbai     ATM    Approved           782
# 1           Credit  18500.00      Delhi  Online    Rejected           641
# 2            Debit    950.50  Bengaluru    Bank    Approved           815
# 3           Credit   4200.25  Hyderabad  Online    Approved           734
# 4            Debit  12750.00    Chennai     ATM    Rejected           602
#
#    Month
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
df.to_excel("bank_Data.xlsx", index=False)

print("Data cleaning completed successfully!")
# Out:
# Data cleaning completed successfully!

# %%
df.groupby('Account_Type')['Amount'].sum()
# Out:
# Account_Type
# Credit      100290.40
# Current     312730.89
# Savings    1478570.99
# Name: Amount, dtype: float64

# %%
df.groupby('Branch')['Amount'].sum()
# Out:
# Branch
# Ahmedabad    138064.89
# Bengaluru    230634.69
# Chennai      217404.30
# Delhi        158886.70
# Hyderabad    135800.90
# Jaipur       224181.60
# Kolkata      241696.50
# Lucknow      194662.90
# Mumbai       191680.15
# Pune         158579.65
# Name: Amount, dtype: float64

# %%
df.groupby('Month')['Amount'].sum()
# Out:
# Month
# 1    269107.13
# 2    268763.80
# 3    267652.25
# 4    299326.10
# 5    300532.05
# 6    299666.00
# 7    186544.95
# Name: Amount, dtype: float64

# %%
df.groupby('Customer_ID')['Amount'].sum().sort_values(ascending=False).head
(10)
# Out:
# 10

# %%
df['Loan_Status'].value_counts(normalize=True) * 100
# Out:
# Loan_Status
# Approved    74.5
# Rejected    25.5
# Name: proportion, dtype: float64

# %%
df['Channel'].value_counts()
# Out:
# Channel
# ATM       67
# Online    67
# Bank      66
# Name: count, dtype: int64
